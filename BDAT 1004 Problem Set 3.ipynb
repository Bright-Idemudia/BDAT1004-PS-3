# %% [markdown]
# ### Question 3

# %%
#step 1
import pandas as pd
import random
import pandas as pd
import random
import datetime
import numpy as np
import seaborn as sns

# %%
#Step 2

series1 = []
series2 = []
series3 = []

for i in range(100):
    
    series1.append
    series2.append
    series3.append
    
    
    rand_num1 = random.randint(1, 4)
    rand_num2 = random.randint(1, 3)
    rand_num3 = random.randint(10000, 30000)
    
    # adding the number to the list each time
    series1.append(rand_num1)
    series2.append(rand_num2)
    series3.append(rand_num3)

# %%
series1 = []
series2 = []
series3 = []

for i in range(100):
    rand_num1 = random.randint(1, 4)
    rand_num2 = random.randint(1, 3)
    rand_num3 = random.randint(10000, 30000)
    
    # adding the number to the list each time
    series1.append(rand_num1)
    series2.append(rand_num2)
    series3.append(rand_num3)

# %%
# step 3
df = pd.DataFrame(list(zip(series1, series2, series3)))

df
# Out:
#     0  1      2
# 0   2  3  26219
# 1   1  2  26003
# 2   2  2  10732
# 3   4  1  12591
# 4   2  3  16823
# .. .. ..    ...
# 95  2  3  10353
# 96  1  1  21776
# 97  1  2  21359
# 98  2  2  23015
# 99  3  1  10518
#
# [100 rows x 3 columns]

# %%
# step 4
df.rename(columns={0: "bedrs", 1: "bathrs", 2:"price_sqr_meter"}, inplace=True)
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       2       3            26219
# 1       1       2            26003
# 2       2       2            10732
# 3       4       1            12591
# 4       2       3            16823
# ..    ...     ...              ...
# 95      2       3            10353
# 96      1       1            21776
# 97      1       2            21359
# 98      2       2            23015
# 99      3       1            10518
#
# [100 rows x 3 columns]

# %%
#step 5 - True. The Length of values does not match length of index. see step 6

df["bigcolumn"] = series1 + series2 + series3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-15ee8ee8203b> in <module>
#       1 #step 5
#       2
# ----> 3 df["bigcolumn"] = series1 + series2 + series3
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# ...

# %%
#step7 - Reindex the DataFrame from 0 to 299
df = df.reindex(list(range(300)))

# %%
#step7 - Reindex the DataFrame from 0 to 299 and call the DataFrame
df["bigcolumn"] = series1 + series2 + series3
df
# Out:
#      bedrs  bathrs  price_sqr_meter  bigcolumn
# 0      2.0     3.0          26219.0          2
# 1      1.0     2.0          26003.0          1
# 2      2.0     2.0          10732.0          2
# 3      4.0     1.0          12591.0          4
# 4      2.0     3.0          16823.0          2
# ..     ...     ...              ...        ...
# 295    NaN     NaN              NaN      10353
# 296    NaN     NaN              NaN      21776
# 297    NaN     NaN              NaN      21359
# 298    NaN     NaN              NaN      23015
# 299    NaN     NaN              NaN      10518
#
# [300 rows x 4 columns]

# %% [markdown]
# ### Question 4

# %%
#step 1 Import the necessary libraries
import datetime
import pandas as pd
import numpy as np

# %%
# step 2 spacing the date
wind_rec_link = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.info"
wind_rec = pd.read_csv(wind_data_link, sep="\s+")
wind_rec
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
#step 3
def to_datetime(year, month, day):
    proper_data = f"19{int(year)}-{int(month)}-{int(day)}"
    return proper_data

# %%
#source: Stackoverflow

wind_rec["date_time"] = wind_rec.apply(lambda x: to_datetime(x['Yr'], x['Mo'], x['Dy']), axis=1)


wind_rec.drop(["Yr","Mo", "Dy"], axis = 1, inplace = True)
wind_info
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# date_time
# 1961-1-1    15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-1-2    14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-1-3    18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-1-4    10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-1-5    13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# date_time
# ...

# %%
wind_rec['date_time'] = pd.to_datetime(wind_rec["date_time"], infer_datetime_format=True)


wind_rec
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL  date_time
# 0     18.50  15.04 1961-01-01
# ...

# %%
#step 5 
# source: #https://pythonpedia.com/en/knowledge-base/29206612/difference-between-data-type--datetime64-ns---and---m8-ns---
print(wind_rec["date_time"].dtypes)
wind_rec.set_index('date_time', inplace=True)
# Out:
# datetime64[ns]

# %%
wind_rec.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# date_time
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# date_time
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %%
#step 6 - using the isnull function
missing_values = wind_rec.isnull().sum()
missing_values
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
# ignoring missing values in all calculations below by using drop function
wind_rec.dropna(inplace=True)
wind_rec
# Out:
#               RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA    MUL  \
# date_time
# 1961-01-04  10.58   6.63  11.75  4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42  6.17  10.71   8.21  11.92   6.54  10.92
# 1961-01-06  13.21   8.12   9.96  6.67   5.37   4.50  10.67   4.42   7.17
# 1961-01-07  13.50  14.29   9.50  4.96  12.29   8.33   9.17   9.29   7.58
# 1961-01-08  10.96   9.75   7.62  5.91   9.62   7.29  14.29   7.62   9.25
# ...           ...    ...    ...   ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62  8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46  5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42  8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29  9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29  9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# date_time
# 1961-01-04   5.88   5.46  10.88
# ...

# %%
#recall mising value
missing_values = wind_rec.isnull().sum()
missing_values
# Out:
# RPT    0
# VAL    0
# ROS    0
# KIL    0
# SHA    0
# BIR    0
# DUB    0
# CLA    0
# MUL    0
# CLO    0
# BEL    0
# MAL    0
# dtype: int64

# %%
#step 7 - using the notnull function after dropping all NaN values
not_missing_values = wind_rec.notnull().sum().sum()
not_missing_values
# Out:
# 78552

# %%
# step 8
wind_rec.mean().mean()
# Out:
# 10.222465245951712

# %%
#step 9 name DataFrame and describe statistics at each location
loc_stats = wind_rec.describe()
loc_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6546.000000  6546.000000  6546.000000  6546.000000  6546.000000
# mean     12.359979    10.640267    11.656396     6.298587    10.448923
# std       5.618805     5.268695     5.007805     3.600942     4.933988
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     7.970000     3.580000     6.750000
# 50%      11.710000    10.130000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.380000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6546.000000  6546.000000  6546.000000  6546.000000  6546.000000
# mean      7.085066     9.793006     8.486601     8.490257     8.696705
# std       3.967735     4.978030     4.498299     4.165947     4.500488
# ...

# %%
# step 10 name DataFrame and describe statistics at each day
day_stats = wind_rec.apply(pd.Series.describe, axis=1)
day_stats
# Out:
#             count       mean       std   min      25%     50%      75%    max
# date_time
# 1961-01-04   12.0   6.619167  3.198126  1.79   4.5700   5.855   9.1175  11.75
# 1961-01-05   12.0  10.630000  2.445356  6.17   9.8075  11.170  12.1700  13.33
# 1961-01-06   12.0   8.240000  2.998063  4.42   6.3450   7.810  10.1375  13.21
# 1961-01-07   12.0  10.385000  3.072114  4.96   8.2375   9.395  13.5725  14.29
# 1961-01-08   12.0  10.487500  3.547237  5.91   7.6200   9.685  11.7925  16.62
# ...           ...        ...       ...   ...      ...     ...      ...    ...
# 1978-12-27   12.0  16.708333  7.868076  8.08  13.8025  15.025  17.3025  40.08
# 1978-12-28   12.0  15.150000  9.687857  5.00   9.0950  13.895  16.7000  41.46
# 1978-12-29   12.0  14.890000  5.756836  8.71  10.4775  14.210  17.0350  29.58
# 1978-12-30   12.0  15.367500  5.540437  9.13  12.3750  13.455  18.1850  28.79
# 1978-12-31   12.0  15.402500  5.702483  9.59  11.5300  12.080  19.5200  27.29
#
# [6546 rows x 8 columns]

# %%
# step 11
jan_avg = wind_rec.loc[wind_rec.index.month==1, :].mean()
jan_avg
# Out:
# RPT    14.831609
# VAL    12.885389
# ROS    13.276275
# KIL     7.152477
# SHA    11.644467
# BIR     8.030561
# DUB    11.788336
# CLA     9.486962
# MUL     9.511501
# CLO    10.024069
# BEL    14.527848
# MAL    18.041826
# dtype: float64

# %%
# step 12 resample yearly frequency for each location
annual_freq = wind_rec.resample('Y').sum()
annual_freq
# Out:
#                 RPT      VAL      ROS      KIL      SHA      BIR      DUB  \
# date_time
# 1961-12-31  4150.58  3470.45  3836.17  2327.79  3652.53  2589.83  3275.31
# 1962-12-31  4443.47  3674.61  4240.60  2521.09  3870.60  2684.35  3997.61
# 1963-12-31  4676.91  3955.50  4577.52  2675.47  4279.30  3078.67  4042.63
# 1964-12-31  4525.10  3996.78  4430.20  2484.33  4192.34  2770.94  3754.85
# 1965-12-31  4544.75  4042.57  4324.80  2503.34  4024.05  2729.51  3875.83
# 1966-12-31  4913.62  4218.38  4387.53  2681.19  4308.84  2844.69  3861.63
# 1967-12-31  4649.06  4011.71  4284.88  2607.35  4245.22  2689.38  3887.99
# 1968-12-31  4331.84  3831.36  4175.97  2370.83  3938.44  2220.64  3242.46
# 1969-12-31  4075.72  3549.15  3979.23  2105.31  3603.98  2259.34  3126.04
# 1970-12-31  4599.12  3915.33  4281.54  2269.27  3857.09  2777.45  3507.61
# 1971-12-31  4114.69  3319.74  4047.24  1913.15  3445.72  2225.46  3060.85
# ...

# %%
#resample monthly frequency for each location.
monthly_freq = wind_rec.resample('M').sum()
monthly_freq
# Out:
#                RPT     VAL     ROS     KIL     SHA     BIR     DUB     CLA  \
# date_time
# 1961-01-31  377.16  291.86  336.97  177.84  273.24  212.53  270.48  225.44
# 1961-02-28  426.45  390.97  376.22  240.31  358.23  283.00  308.57  305.40
# 1961-03-31  287.82  299.63  281.34  191.72  277.17  231.66  245.93  251.89
# 1961-04-30  321.68  282.83  299.94  174.92  253.05  194.85  207.76  212.84
# 1961-05-31  280.69  237.88  295.10  167.79  265.45  185.75  214.08  229.79
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 1978-08-31  299.00  256.04  280.00  139.59  228.41  183.99  175.16  167.95
# 1978-09-30  327.41  326.85  319.05  171.75  311.16  278.35  323.71  287.49
# 1978-10-31  306.83  268.80  288.17  146.36  264.28  210.00  251.58  227.47
# 1978-11-30  484.55  444.08  405.24  219.52  344.25  262.29  344.77  289.72
# 1978-12-31  501.44  426.19  484.69  219.94  353.36  286.49  374.40  316.04
#
#                MUL     CLO     BEL     MAL
# date_time
# ...

# %%
# step 14 resample weekly frequency for each location.
weekly_freq = wind_rec.resample('W').sum()
weekly_freq
# Out:
#                RPT     VAL     ROS    KIL     SHA    BIR     DUB    CLA  \
# date_time
# 1961-01-08   61.58   52.04   50.25  28.29   42.53  31.21   54.68  29.66
# 1961-01-15   87.28   62.77   83.71  32.41   51.46  35.51   52.75  47.74
# 1961-01-22   72.60   57.00   70.09  25.76   53.80  41.63   46.97  43.75
# 1961-01-29  119.28   89.08  105.29  71.50   97.95  84.10   86.70  85.87
# 1961-02-05  117.79  108.22   88.33  57.73   93.53  63.75   85.43  59.84
# ...            ...     ...     ...    ...     ...    ...     ...    ...
# 1978-12-03  104.54   78.63   97.59  38.96   71.51  60.33   67.50  53.80
# 1978-12-10  145.18  134.33  119.24  68.44  107.01  89.42  101.06  87.42
# 1978-12-17  117.31  102.85  104.91  48.42   79.78  50.91   71.46  55.77
# 1978-12-24   78.09   56.06   92.21  28.03   54.78  44.03   54.59  60.67
# 1978-12-31  104.66   82.61  112.25  45.55   67.62  60.34   95.96  73.34
#
#               MUL    CLO     BEL     MAL
# date_time
# ...

# %% [markdown]
# ### Question 5

# %%
#step 1 import necessary library
import pandas as pd

# %%
#step 2, 3 & 4
data_address = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

chipo = pd.read_csv(data_address, sep='\t')
chipo.head (10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#step 5
num_observtn = chipo.shape[0]

print(f"number of observation is {num_observtn}")
# Out:
# number of observation is 4622

# %%
#step 6
num_columns = chipo.shape[1]
print(f"number of columns is {num_columns}")
# Out:
# number of columns is 5

# %%
#step 7
print (chipo.columns.values)
# Out:
# ['order_id' 'quantity' 'item_name' 'choice_description' 'item_price']

# %%
#8 question not clear

# %%
# step 9
most_ordered_qty = chipo.groupby(['item_name'])[['quantity']].sum() .max()
most_ordered_qty
# Out:
# quantity    761
# dtype: int64

# %%
 chipo.item_name.value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
#Step 10 For the most-ordered item, how many items were ordered?
most_ordered = order_qty[order_qty.quantity == order_qty.quantity.max()]
most_ordered
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %%
#step 11 
order_qty = chipo.groupby(['choice_description'])[['quantity']].sum()
order_qty
# Out:
#                                                     quantity
# choice_description
# [Adobo-Marinated and Grilled Chicken, Pinto Bea...         1
# [Adobo-Marinated and Grilled Chicken, [Sour Cre...         1
# [Adobo-Marinated and Grilled Chicken]                      1
# [Adobo-Marinated and Grilled Steak, [Sour Cream...         1
# [Adobo-Marinated and Grilled Steak]                        1
# ...                                                      ...
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         2
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1
#
# [1043 rows x 1 columns]

# %%
#step 12
order_qty['quantity'].sum()
# Out:
# 4972

# %%
#step 13
print (chipo['item_price'].dtypes)
# Out:
# object

# %%
def turn_to_float(dollar):
    price = dollar[1:]
    price_float = float(price)
    return price_float
convert = turn_to_float('$4.05')
convert
# Out:
# 4.05

# %%
chipo['item_price'] = chipo.apply(lambda x: turn_to_float(x['item_price']), axis = 1)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
print(chipo['item_price'].dtypes)
# Out:
# float64

# %%
#step14 total revenue
revenue = (chipo['quantity']*chipo['item_price']).sum()
revenue
# Out:
# 39237.02

# %%
#15 How many orders were made in the period?
no_of_orders = chipotle['quantity'].sum()
no_of_orders
# Out:
# 4972

# %%
#step 16 What is the average revenue amount per order
avg_rev_per_ord = round(revenue/no_of_orders, 2)
avg_rev_per_ord
# Out:
# 7.89

# %%
#17 How many different items are sold?
chipotle['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# ### Question 6
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import matplotlib.pyplot as plt

# %%
file_location = r"C:\Users\brigh\Desktop\us-marriages-divorces-1867-2014.csv"
marriage_divorce = pd.read_csv(file_location)

marriage_divorce.set_index('Year', inplace=True)

# %%
marriage_divorce[["Marriages_per_1000", "Divorces_per_1000"]].plot(kind='line')


plt.ylabel('Divorce and Marriage per capita')
# Out:
# Text(0, 0.5, 'Divorce and Marriage per capita')

# %% [markdown]
# ### Question 7
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
Marriage_barchart = marriage_divorce[marriage_divorce.index.isin([1900, 1950,2000])]
Marriage_barchart
# Out:
#       Marriages  Divorces  Population  Marriages_per_1000  Divorces_per_1000
# Year
# 1900   709000.0   56000.0    76094000                 9.3                0.7
# 1950  1667000.0  385000.0   151684000                11.0                2.5
# 2000  2315000.0  944000.0   282398000                 8.2                3.3

# %%
Marriage_barchart[["Marriages_per_1000", "Divorces_per_1000"]].plot(kind='bar')

# %% [markdown]
# ### Question 8

# %%
actor_kills = pd.read_csv(r'C:\Users\brigh\Desktop\actor_kill_counts (1).csv')

# %%
actor_kills
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
# %matplotlib inline

# %%
actor_kills.plot(kind='barh')

# %% [markdown]
# ### Question 9
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
file_locatn = r"C:\Users\brigh\Desktop\roman-emperor-reigns.csv"
emperor = pd.read_csv(file_locatn)
emperor.head()
# Out:
#     Emperor  Length_of_Reign         Cause_of_Death
# 0  Augustus            40.58  Possibly assassinated
# 1  Tiberius            22.50  Possibly assassinated
# 2  Caligula             4.83           Assassinated
# 3  Claudius            13.75  Possibly assassinated
# 4      Nero            13.67                Suicide

# %%
romans_chart = emperor[ "Cause_of_Death"].value_counts()
romans_chart.plot(kind='pie')

# %% [markdown]
# ### Question 10
#
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
file_locatn = r"C:\Users\brigh\Desktop\arcade-revenue-vs-cs-doctorates.csv"
arcdoc = pd.read_csv(file_locatn)

# %%
arcdoc
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
# create color dictionary
colors = {'arcdoc': 'r', 'arcdoc-versicolor': 'g', 'arcdoc-virginica':'b'}

fig, ax = plt.subplots()

for i in range(len(arcdoc['Total Arcade Revenue (billions)'])):
    ax.scatter(arcdoc['Total Arcade Revenue (billions)'][i], arcdoc['Computer Science Doctorates Awarded (US)'][i])

ax.set_title('Arcade Revenue and Computer Science Doctorates')
ax.set_xlabel('Total Arcade Revenue (billions)')
ax.set_ylabel('Computer Science Doctorates Awarded (US)')
# Out:
# Text(0, 0.5, 'Computer Science Doctorates Awarded (US)')
